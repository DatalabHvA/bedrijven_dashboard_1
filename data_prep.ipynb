# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('data_template DFP V3.xlsx')

# %%
df
# Out:
#     Unnamed: 0                 bedrijfsnaam            producten  \
# 0            1              4 Fruit Company       Fruit, groente
# 1            2        4 Potato Holland B.V.           Aardappels
# 2            3           A.F.L. Barendrecht       Fruit, groente
# 3            4             Agrofair Benelux                Fruit
# 4            5      Allround Cargo Handling                  NaN
# ..         ...                          ...                  ...
# 56          57            VerDi Import B.V.       Groeten, fruit
# 57          58            Verita Holland BV                Fruit
# 58          59             Very Fruity B.V.       Fruit (retail)
# 59          60      VGK Cool Logistics B.V.  Koel/vrieslogistiek
# 60          61  Zoutewelle Import Export BV      Groenten, fruit
#
#                                                sector  fossiel trucks  \
# 0                                              Handel               0
# ...
